# %% [markdown]
# <a href="https://colab.research.google.com/github/Siri-2256/SML_2303A52256_B43/blob/main/project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/Copy of Top_spotify_tracks_of_2018(1).csv')
df
# Out:
#                        id                               name       artists  \
# 0   6DCZcSspjsKoFjzjrWoCd                         God's Plan         Drake
# 1   3ee8Jmje8o58CHK66QrVC                               SAD!  XXXTENTACION
# 2   0e7ipj03S05BNilyu5bRz         rockstar (feat. 21 Savage)   Post Malone
# 3   3swc6WTsr7rl9DqQKQA55       Psycho (feat. Ty Dolla $ign)   Post Malone
# 4   2G7V7zsVDxg1yRsu7Ew9R                     In My Feelings         Drake
# ..                    ...                                ...           ...
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
#
# ...

# %%
target=df['duration_ms']
target
# Out:
# 0     198973
# 1     166606
# 2     218147
# 3     221440
# 4     217925
#        ...
# 95    217440
# 96    205748
# 97    260000
# 98    239000
# 99    196373
# Name: duration_ms, Length: 100, dtype: int64

# %%
x=df.drop(['duration_ms','id','name','artists'],axis=1)
x
# Out:
#     danceability       energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.754        0.449    7    -9.211     1       0.1090        0.0332
# 1          0.740        0.613    8    -4.880     1       0.1450        0.2580
# 2          0.587        0.535    5    -6.090     0       0.0898        0.1170
# 3          0.739        0.559    8    -8.011     1       0.1170        0.5800
# 4          0.835        0.626    1    -5.833     1       0.1250        0.0589
# ..           ...          ...  ...       ...   ...          ...           ...
# 95         0.684        0.619   10    -7.005     1       0.0386        0.0716
# 96         0.638        0.658    3    -6.318     1       0.0456        0.2450
# 97         0.552        0.760    0    -4.706     1       0.3420        0.0733
# 98         0.258        0.437   11    -6.593     0       0.0390        0.1010
# 99         0.553        0.586   11    -6.319     1       0.0362        0.6970
#
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,target,test_size=0.2)

# %%
x_test
# Out:
#     danceability       energy  key  loudness  mode  speechiness  acousticness  \
# 2          0.587        0.535    5    -6.090     0       0.0898        0.1170
# 89         0.909        0.493    3    -6.688     1       0.0735        0.1280
# 31         0.737        0.636   11    -4.546     0       0.0437        0.0441
# 25         0.825        0.652    1    -3.183     0       0.0802        0.5810
# 29         0.599        0.448    8    -6.312     1       0.0232        0.1630
# 0          0.754        0.449    7    -9.211     1       0.1090        0.0332
# 18         0.921        0.537    9    -5.723     0       0.0804        0.5560
# 27         0.642        0.772   10    -6.610     1       0.0848        0.0476
# 38         0.669        0.308   11   -10.068     1       0.0290        0.8830
# 63         0.622        0.712    5    -7.321     1       0.0660        0.0573
# 40         0.748        0.749    8    -5.916     0       0.5160        0.1420
# ...

# %%
y_test
# Out:
# 2     218147
# 89    197120
# 31    222653
# 25    233713
# 29    263400
# 0     198973
# 18    135090
# 27    164205
# 38    121887
# 63    211360
# 40    221013
# 3     221440
# 90    213309
# 66    220117
# 39    184560
# 34    173720
# 87    226800
# 9     202621
# 67    194680
# 80    200186
# Name: duration_ms, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# -0.01634637282406115

# %%
MSE=model.score(x_test,y_test)
MSE
# Out:
# -0.01634637282406115

# %%
MAE=model.score(x_train,y_train)
MAE
# Out:
# 0.20016678339634053

# %%
RMSE=model.score(x_test,y_test)
RMSE
# Out:
# -0.01634637282406115

# %%
from sklearn.linear_model import Ridge
model=Ridge()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.027951571590678292

# %%
MSE=model.score(x_test,y_test)
MSE
# Out:
# 0.027951571590678292

# %%
MAE=model.score(x_train,y_train)
MAE
# Out:
# 0.18166160585826774

# %%
RMSE=model.score(x_test,y_test)
RMSE
# Out:
# 0.027951571590678292

# %%
from sklearn.linear_model import Lasso
model=Lasso()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# -0.01590474723881763

# %%
MSE=model.score(x_test,y_test)
MSE
# Out:
# -0.01590474723881763

# %%
MAE=model.score(x_train,y_train)
MAE
# Out:
# 0.20016369236821463

# %%
RMSE=model.score(x_test,y_test)
RMSE
# Out:
# -0.01590474723881763

# %%
from sklearn.svm import SVR
model=SVR()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# -0.013824763359504999
